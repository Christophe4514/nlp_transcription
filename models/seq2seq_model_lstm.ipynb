# %%
### Importing utilities
from __future__ import unicode_literals, print_function, division
import pandas as pd
import numpy as np
import time
import math
import pickle

import matplotlib.pyplot as plt
#plt.switch_backend('agg')
import matplotlib.ticker as ticker
from prettytable import PrettyTable

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import  nltk.translate.bleu_score as bleu
from matplotlib.font_manager import FontProperties

from io import open
import unicodedata
import string
import re
import random
import warnings
warnings.filterwarnings("ignore")

# %%
### Some parameters (Details in coming sections)
SOS_token = 0
EOS_token = 1
UNK_token = 2

MAX_LENGTH = 20
teacher_forcing_ratio = 0.5
hidden_size = 1000

# %% [markdown]
# # 2. Data Preparation¶
#
# The data for this task is a set of many English to hindi translation pairs. The Hindi-English Corpora available on Kaggle can also be used here.

# %%
data = open('/content/fichier_sans_lignes_vides.csv', encoding='utf-8').\
        read().strip().split('\n')
pairs = [[s for s in l.split('\t')[:2]] for l in data]
pairs[5]
# Out:
# ['"Et Dieu nomma la lumière, jour; et il nomma les ténèbres, nuit. Et il y eut un soir, et il y eut un matin; ce fut le premier jour.","Nzambe abengaki pole «\xa0moyi,\xa0» mpe abengaki molili «\xa0butu.\xa0» Pokwa ezalaki mpe tongo ezalaki. Yango ezalaki mokolo moko."']

# %%
if(pairs):
  print("okay")
# Out:
# okay

# %% [markdown]
# Now, we need the data in a format that is easy to process and feed. We’ll need a unique index per word to use as the inputs and targets of the networks later. To keep track of all this we will use a helper class called Lang which has word → index (word2index) and index → word (index2word) dictionaries, as well as a count of each word word2count to use to later replace rare words.

# %%
class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {"SOS": 0, "EOS": 1, "UNK": 2}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS", 2: "UNK"}
        self.n_words = 3  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# A function to turn Unicode characters to ASCII if needed. Another function to make everything lowercase, and trim most punctuation.

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters


def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    return s

# %% [markdown]
# A function to read the data and to create objects of the Lang Class

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Started Loading Data...")
    print("Reading lines...")


   # Read the file and split into lines
    lines = open('/content/fichier_sans_lignes_vides.csv'.format(lang1, lang2), encoding='utf-8').\
    read().strip().split('\n')

    #print(lines)

    # Split every line into pairs and normalize
    pairs = [[s for s in l.split('\t')[:2]] for l in lines]

    #print(pairs)
    print("len", len(pairs))
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %% [markdown]
# A function to filter data based on sequence lenght if needed

# %%
def filterPair(p):
    #print(p[1])
    try:
        return len(p[0].split(' ')) < MAX_LENGTH and \
            len(p[1].split(' ')) < MAX_LENGTH
    except:
        print("Skipped this pair : ", p)


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# A wrapper function to do the data preparation steps

# %%
# def prepareData(lang1, lang2, reverse=False):
#     input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
#     print("Read %s sentence pairs" % len(pairs))
#     pairs = filterPairs(pairs)
#     print("Trimmed to %s sentence pairs" % len(pairs))
#     print("Counting words...")
#     for pair in pairs:
#         input_lang.addSentence(pair[0])
#         output_lang.addSentence(pair[1])
#     print("Counted words:")
#     print(input_lang.name, input_lang.n_words)
#     print(output_lang.name, output_lang.n_words)
#     return input_lang, output_lang, pairs

def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)

    if not pairs:
        print(f"Error: The file '/content/fichier_sans_lignes_vides.csv' does not exist or is empty.")
        return None, None, None

    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
#  ['Ils leur dirent: C\'est une chose que nous ne pouvons faire que de donner notre sœur à un homme incirconcis; car ce nous serait un opprobre.,"Balobaki na bango\xa0: — Tokoki kosala likambo ya boye te, tokoki te kopesa na libala ndeko na biso ya mwasi epai ya mobali oyo akatama ngenga te, pamba te ezali likambo ya soni mpo na biso."'],
#  ['"Nous ne consentirons à ce que vous demandez que si vous devenez semblables à nous, en circoncisant tous les mâles parmi vous.","Tokoki kondima yango kaka soki bokomi lokola biso, soki bana na bino nyonso ya mibali bakatisi ngenga."'],
#  ['"Alors nous vous donnerons nos filles, et nous prendrons vos filles pour nous; et nous habiterons avec vous, et nous ne serons plus qu\'un peuple.",Boye biso tokopesa na libala bana na biso ya basi mpe tokozwa bana na bino ya basi na libala. Tokovanda elongo na bino mpe tokokoma libota moko.'],
#  ['"Mais, si vous ne voulez pas nous écouter et vous circoncire, nous prendrons notre fille, et nous nous en irons.","Kasi soki boboyi kokatisa ngenga ndenge biso tolobi, tokozwa ndeko na biso ya mwasi mpe tokokende na biso."'],
#  ['"Et leurs discours plurent à Hémor et à Sichem, fils de Hémor.","Likanisi na bango emonanaki malamu epai ya Amori mpe Sishemi, mwana na ye ya mobali."'],
#  ...]

# %%
input_lang, output_lang, pairs = prepareData('français', 'lingala', False)
print("Data Loaded....See Example below - ")
print(random.choice(pairs))

# input_lang, output_lang, pairs = prepareData('français', 'lingala', False)
# if input_lang is None and output_lang is None and pairs is None:
#     print("Error: Unable to load data. Please check the file path and existence.")
# else:
#     print("Data Loaded....See Example below - ")
#     print(random.choice(pairs))

# if pairs:
#     print("Data Loaded....See Example below - ")
#     print(random.choice(pairs))
# else:
#     print("Aucune donnée disponible.")
# Out:
# Started Loading Data...
# Reading lines...
# len 31171
# Read 31171 sentence pairs
# Skipped this pair :  ['francais lingala']
# Skipped this pair :  ['mais noe trouva grace aux yeux de l eternel . kasi noa azwaki ngolu na miso ya yawe .']
# Skipped this pair :  [' alors dieu parla a noe en disant boye nzambe alobaki na noa ']
# Skipped this pair :  [' les jebusiens les amoreens les guirgasiens ya yebusi ya amori ya girigazi ']
# Skipped this pair :  [' les heviens les arkiens les siniens ya evi ya ariki ya sini ']
# Skipped this pair :  [' et arpacshad engendra shelach et shelach engendra heber . aripakishadi abotaki shela shela abotaki eberi .']
# Skipped this pair :  [' et jockthan engendra almodad sheleph hatsarmaveth et jerach yokitani abotaki alimodadi shelefi atsarimaveti yera ']
# Skipped this pair :  [' hadoram uzal dikla adorami uzali dikila ']
# Skipped this pair :  [' obal abimael sheba obali abimaeli saba ']
# Skipped this pair :  ['mais sarai etait sterile elle n avait point d enfant . sarayi azalaki ekomba azalaki na mwana te .']
# Skipped this pair :  ['et abraham repondit je le jurerai . abrayami azongisaki nalapi ndayi !']
# Skipped this pair :  ['et abraham sejourna longtemps au pays des philistins . abrayami avandaki lisusu tango molayi na mokili ya filisitia .']
# Skipped this pair :  [' kesed hazo pildash jidlaph et bethuel . kesedi azo pilidashi yidilafi mpe betweli . ']
# Skipped this pair :  [' et les enfants de heth repondirent a abraham en lui disant bato ya iti bazongiselaki abrayami ']
# Skipped this pair :  ['et abraham se prosterna devant le peuple du pays abrayami agumbamaki liboso ya bato ya mboka']
# Skipped this pair :  [' et ephron repondit a abraham en lui disant efroni azongiselaki abrayami ']
# Skipped this pair :  ['alors il dit je suis serviteur d abraham . azongisaki nazali mosali ya abrayami .']
# Skipped this pair :  [' or abraham prit une autre femme nommee ketura abrayami abalaki mwasi mosusu kombo na ye ketura . ']
# Skipped this pair :  [' mishma duma massa mishima duma masa ']
# Skipped this pair :  [' hadar thema jethur naphish et kedma . adadi tema yeturi nafishi mpe kedima . ']
# Skipped this pair :  ['isaac demeura donc a guerar . boye izaki avandaki na gerari . ']
# Skipped this pair :  ['et de la il monta a beer sheba . kolongwa wana akendeki na beri sheba . ']
# Skipped this pair :  ['les fils de rachel joseph et benjamin . bana mibali ya rasheli jozefi mpe benjame .']
# Skipped this pair :  [' or voici les descendants d esau qui est edom . tala libota ya ezawu oyo azali edomi .']
# Skipped this pair :  ['voici les fils de dishan uts et aran . bana mibali ya dishani utsi mpe arani .']
# Skipped this pair :  [' le chef oholibama le chef ela le chef pinon olibama ela pinoni ']
# Skipped this pair :  [' le chef kenaz le chef theman le chef mibtsar kenazi temani mibitsari ']
# Skipped this pair :  [' or la famine etait fort grande dans le pays . nzala makasi ekotaki kati na mokili .']
# Skipped this pair :  ['les fils de dan hushim . mwana mobali ya dani ushimi .']
# Skipped this pair :  [' j ai attendu ton salut o eternel ! oh yawe nazali na elikya ete okobikisa ngai ! ']
# Skipped this pair :  [' ruben simeon levi et juda ribeni simeoni levi mpe yuda ']
# Skipped this pair :  [' issacar zabulon et benjamin isakari zabuloni mpe benjame ']
# Skipped this pair :  [' dan et nephtali gad et asser . dani mpe nefitali gadi mpe aseri .']
# Skipped this pair :  [' et l eternel parla a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' et l eternel parla a moise et a aaron en disant yawe alobaki na moyize mpe aron ']
# Skipped this pair :  ['toute l assemblee d israel fera la paque . lisanga mobimba ya isalaele ekosala feti ya pasika .']
# Skipped this pair :  [' et l eternel parla a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' et l eternel parla a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  ['l eternel regnera eternellement et a toujours . yawe akotikala mokonzi libela na libela !']
# Skipped this pair :  [' et l eternel parla a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  ['le peuple se reposa donc le septieme jour . boye bato bapemaki na mokolo ya sambo .']
# Skipped this pair :  [' alors dieu prononca toutes ces paroles en disant tala maloba oyo nzambe alobaki ']
# Skipped this pair :  ['souviens toi du jour du repos pour le sanctifier kanisaka mokolo ya saba mpe bulisaka yango .']
# Skipped this pair :  [' tu travailleras six jours et tu feras toute ton uvre okosalaka misala na yo nyonso mikolo motoba .']
# Skipped this pair :  ['tu ne tueras point . okobomaka te .']
# Skipped this pair :  ['tu ne commettras point adultere . okosalaka ekobo te .']
# Skipped this pair :  ['tu ne deroberas point . okoyibaka te .']
# Skipped this pair :  ['tu ne laisseras point vivre la sorciere . okotika te na bomoi mwasi oyo asalaka maji .']
# Skipped this pair :  ['vous n affligerez aucune veuve ni aucun orphelin . bokonyokola te mwasi oyo akufisa mobali to mwana etike .']
# Skipped this pair :  [' et l eternel parla a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' tu feras aussi des agrafes d or okotia bikangelo ya wolo']
# Skipped this pair :  [' l eternel parla aussi a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' l eternel parla encore a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' l eternel parla aussi a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' l eternel parla aussi a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' l eternel parla encore a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  ['et moise s inclina aussitot vers la terre et se prosterna mbala moko moyize afukamaki mpe agumbamelaki yawe ']
# Skipped this pair :  ['tu ne te feras point de dieu de fonte . bokosala nzambe ya ekeko te .']
# Skipped this pair :  [' et l eternel parla a moise en disant yawe alobaki na moyize ']
# Skipped this pair :  [' l eternel parla encore a moise en disant yaw
# Skipped this pair :  ['tu ne tueras point . okobomaka te .']
# Skipped this pair :  ['tu ne commettras point adultere . okosalaka ekobo te .']
# Skipped this pair :  ['tu ne deroberas point . okoyibaka te .']
# Skipped this pair :  [' va dis leur retournez dans vos tentes kende yebisa bango bozonga na bandako na bino . ']
# Skipped this pair :  ['tu ne mangeras aucune chose abominable . bokoki te kolia ata eloko moko ya mbindo .']
# Skipped this pair :  ['vous mangerez tout oiseau pur . bokolia ndeke nyonso oyo ezangi mbindo .']
# Skipped this pair :  [' et tout corbeau selon son espece bayanganga ya lolenge nyonso ']
# Skipped this pair :  [' la chouette le hibou le cygne esulungutu esulungutu ya monene esulungutu ya pembe ']
# Skipped this pair :  [' le pelican le cormoran le plongeon libeke ndeke oyo eliaka misuni ya kopola libata ya mayi ']
# Skipped this pair :  ['vous mangerez tout oiseau pur . nzokande bokoki kolia nyonso oyo ezali na mapapu mpe ezangi mbindo . ']
# Skipped this pair :  ['alors l eternel me dit ils ont bien parle yawe alobaki na ngai makambo oyo balobi ezali malamu .']
# Skipped this pair :  [' or l eternel parla a josue en disant yawe alobaki na jozue ']
# Skipped this pair :  ['josue fit longtemps la guerre contre tous ces rois . jozue abundisaki bakonzi wana nyonso tango molayi .']
# Skipped this pair :  [' le roi de jerusalem le roi de hebron mokonzi ya yelusalemi moko mokonzi ya ebron moko']
# Skipped this pair :  [' le roi de jarmuth le roi de lakis mokonzi ya yarimuti moko mokonzi ya lakishi moko']
# Skipped this pair :  [' le roi d eglon le roi de guezer mokonzi ya egiloni moko mokonzi ya gezeri moko']
# Skipped this pair :  [' le roi de debir le roi de gueder mokonzi ya debiri moko mokonzi ya gederi moko']
# Skipped this pair :  [' le roi de horma le roi d arad mokonzi ya orima moko mokonzi ya aradi moko']
# Skipped this pair :  [' le roi de libna le roi d adullam mokonzi ya libina moko mokonzi ya adulami moko']
# Skipped this pair :  [' le roi de makkeda le roi de bethel mokonzi ya makeda moko mokonzi ya beteli moko']
# Skipped this pair :  [' le roi de thappuach le roi de hepher mokonzi ya tapua moko mokonzi ya eferi moko']
# Skipped this pair :  [' le roi d aphek le roi de saron mokonzi ya afeki moko mokonzi ya lasharoni moko']
# Skipped this pair :  [' le roi de madon le roi de hatsor mokonzi ya madoni moko mokonzi ya atsori moko']
# Skipped this pair :  [' le roi de shimron meron le roi d acshaph mokonzi ya shimironi meroni moko mokonzi ya akishafi moko']
# Skipped this pair :  [' le roi de thaanac le roi de meguiddo mokonzi ya taanaki moko mokonzi ya megido moko']
# Skipped this pair :  [' et jahats et kedemoth et mephaath yakatsi kedemoti mefati ']
# Skipped this pair :  [' kina dimona adeada kina dimona adada ']
# Skipped this pair :  [' kedes hatsor jithnan kedeshi atsori itinani ']
# Skipped this pair :  [' ziph telem bealoth zifi telemi bealoti ']
# Skipped this pair :  [' hatsor hadattha kerijoth hetsron qui est hatsor atsori adata kerioti etsironi oyo bazalaki mpe kobenga atsori ']
# Skipped this pair :  [' amam shema molada amami shema molada ']
# Skipped this pair :  [' hatsar gadda heshmon beth palet atsari gada eshimoni beti paleti ']
# Skipped this pair :  [' hatsar shual beer sheba bizjothja atsari shuwali beri sheba biziotia ']
# Skipped this pair :  [' baala ijjim atsem baala iyimi atsemi ']
# Skipped this pair :  [' eltholad kesil horma elitoladi kesili orima ']
# Skipped this pair :  [' tsiklag madmanna sansanna tsikilagi madimana sanisana ']
# Skipped this pair :  [' zanoach en gannim thappuach enam zanoa eyini ganimi tapua enami ']
# Skipped this pair :  [' jarmuth adullam soco azeka yarimuti adulami soko azeka ']
# Skipped this pair :  [' tsenan hadasha migdal gad tsenani adasha migidali gadi ']
# Skipped this pair :  [' dilan mitspe joktheel dileani mitsipe yokiteyeli ']
# Skipped this pair :  [' lakis botskath eglon lakishi botsikati egiloni ']
# Skipped this pair :  [' cabbon lachmas kithlish kaboni lakimasi kitilishi ']
# Skipped this pair :  [' libna ether ashan libina eteri ashani ']
# Skipped this pair :  [' jiphtach ashna netsib yifita ashina netsibi ']
# Skipped this pair :  [' et dans la montagne shamir jatthir soco na mokili ya bangomba shamiri yatiri soko ']
# Skipped this pair :  [' danna kirjath sanna qui est debir dana kiriati sana oyo bazalaki mpe kobenga debiri ']
# Skipped this pair :  [' anab eshthemo anim anabi eshitemoa animi ']
# Skipped this pair :  [' arab duma eshean arabi duma esheani ']
# Skipped this pair :  [' janum beth thappuach apheka yanumi beti tapua afeki ']
# Skipped this pair :  [' maon carmel ziph juta maoni karimeli zifi yuta ']
# Skipped this pair :  [' jizreel jokdeam zanoach jizireyeli yokideami zanoa ']
# Skipped this pair :  [' halhul beth tsur guedor aliwuli beti tsuri gedori ']
# Skipped this pair :  [' dans le desert beth araba middin secaca tala bingumba oyo ezalaki na esobe beti araba midini sekaka ']
# Skipped this pair :  [' beth araba tsemaraim bethel beti araba tsemarayimi beteli ']
# Skipped this pair :  [' avvim para ophra avimi para ofira ']
# Skipped this pair :  [' gabaon rama beeroth gabaoni rama beyeroti ']
# Skipped this pair :  [' mitspe kephira motsa mitsipe kefira motsa ']
# Skipped this pair :  [' rekem jirpeel thareala rekemi yiripeyeli tareala ']
# Skipped this pair :  [' et ils eurent dans leur heritage beer sheba sheba molada bazwaki lokola libula beri sheba sheba molada ']
# Skipped this pair :  [' hatsar shual bala atsem atsari shuwali bala atsemi ']
# Skipped this pair :  [' eltholad bethul horma elitoladi betuli orima ']
# Skipped this pair :  [' tsiklag beth marcaboth hatsar susa tsikilagi beti marikaboti atsari suza ']
# Skipped this pair :  [' hapharaim shion anacharath afarayimi shiyoni anakarati ']
# Skipped this pair :  [' rabbith kishjon abets rabiti kishioni abetsi ']
# Skipped this pair :  [' adama rama hatsor adama rama atsori ']
# Skipped this pair :  [' kedes edrei en hatsor kedeshi edreyi eyini atsori ']
# Skipped this pair :  [' shaalabbin ajalon jithla shaalabini ayaloni yitila ']
# Skipped this pair :  [' elon thimnatha ekron eloni timinata ekroni ']
# Skipped this pair :  [' eltheke guibbethon baalath eliteke gibetoni baalati ']
# Skipped this pair :  [' jehud bene berak gath rimmon yeudi bene beraki gati rimoni ']
# Skipped this pair :  [' alors la parole de l eternel fut adressee a salomon en ces termes yawe alobaki na salomo ']
# Skipped this pair :  ['et il couvrit d or les cherubins . salomo abambaki basheribe yango wolo .']
# Skipped this pair :  ['et la parole de l eternel lui fut adressee en ces termes bongo yawe alobaki na eliya ']
# Skipped this pair :  ['alors la parole de l eternel lui fut adressee en ces termes yawe alobaki na eliya ']
# Skipped this pair :  [' adam seth enosh adamu seti enoshi ']
# Skipped this pair :  [' kenan mahalaleel jered kenani maalalele yeredi ']
# Skipped this pair :  [' henoc metushelah lemec enoki metusalemi lemeki ']
# Skipped this pair :  [' noe sem cham et japhet . noa semi cham mpe jafeti . ']
# Skipped this pair :  [' fils de gomer ashkenaz diphath et togarma . bana mibali ya gomeri ashikenazi difati mpe togarima . ']
# Skipped this pair :  [' les jebusiens les amoreens les guirgasiens ya yebusi ya amori ya girigazi ']
# Skipped this pair :  [' les heviens les arkiens les siniens ya evi ya ariki ya sini ']
# Skipped this pair :  [' les arvadiens les tsemariens et les hamathiens . ya arivadi ya tsemari mpe ya amati . ']
# Skipped this pair :  ['arpacshad engendra shelach et shelach engendra heber . aripakishadi abotaki shela mpe shela abotaki eberi . ']
# Skipped this pair :  [' jockthan engendra almodad sheleph hatsarmaveth jerach yokitani abotaki alimodadi shelefi atsarimaveti yera ']
# Skipped this pair :  [' hadoram uzal dikla adorami uzali dikila ']
# Skipped this pair :  [' ebal abimael sheba obali abimaeli saba ']
# Skipped this pair :  [' sem arpacshad shelach semi aripakishadi shela ']
# Skipped this pair :  [' heber peleg rehu eberi pelegi rewu ']
# Skipped this pair :  [' serug nachor thare serugi naori tera ']
# Skipped this pair :  [' abram qui est abraham . mpe abrami oyo azali abrayami .']
# Skipped this pair :  ['fils d abraham isaac et ismael . bana mibali ya abrayami izaki mpe isimaeli .']
# Skipped this pair :  [' mishma duma massa hadan thema mishima duma masa adadi tema ']
# Skipped this pair :  [' le chef oholibama le chef ela le chef pinon olibama ela pinoni ']
# Skipped this pair :  [' le chef kenaz le chef theman le chef mibtsar kenazi temani mibitsari ']
# Skipped this pair :  [' dan joseph benjamin nephthali gad et asser . dani jozefi benjame nefitali gadi mpe aseri . ']
# Skipped this pair :  ['fils de pharets hetsron et hamul . bana mibali ya peretsi etsironi mpe amuli .']
# Skipped this pair :  ['fils d ethan azaria . mwana mobali ya etani azaria .']
# Skipped this pair :  ['nahasshon engendra salma . salma engendra booz . nashoni azalaki tata ya salima salima azalaki tata ya boazi .']
# Skipped this pair :  [' nathanael le quatrieme raddai le cinquieme ya minei netaneeli ya mitano radayi ']
# Skipped this pair :  [' otsem le sixieme david le septieme . ya motoba otsemi mpe ya sambo davidi . ']
# Skipped this pair :  ['attai engendra nathan nathan engendra zabad atayi azalaki tata ya natan natan azalaki tata ya zabadi . ']
# Skipped this pair :  ['zabad engendra ephlal ephlal engendra obed zabadi azalaki tata ya efilali efilali azalaki tata ya obedi . ']
# Skipped this pair :  ['obed engendra jehu jehu engendra azaria obedi azalaki tata ya jewu jewu azalaki tata ya azaria . ']
# Skipped this pair :  ['azaria engendra helets helets engendra elasa azaria azalaki tata ya eletsi eletsi azalaki tata ya eleasa . ']
# Skipped this pair :  ['elasa engendra sismai sismai engendra shallum eleasa azalaki tata ya sisimayi sisimayi azalaki tata ya shalumi . ']
# Skipped this pair :  [' jibhar elishama eliphelet babotelaki ye lisusu bana oyo yibari elishama elifeleti ']
# Skipped this pair :  [' noga nepheg japhia noga nefegi yafia ']
# Skipped this pair :  [' elishama eljada et eliphelet neuf . elishama eliyada mpe elifeleti . bango nyonso bazalaki libwa . ']
# Skipped this pair :  [' fils de jehojakim jechonias son fils sedecias son fils . bana mibali ya yeoyakimi yekonia mpe sedesiasi .']
# Skipped this pair :  [' fils de jechonias captif salathiel son fils libota ya yekonia mokangami shealitieli mwana na ye ya mobali ']
# Skipped this pair :  [' malkiram pedaja shenatsar jekamia hoshama et nedabia . malikirami pedaya shenatsari yekamia oshama mpe nedabia . ']
# Skipped this pair :  [' a bilha a etsem a tholad na bila na etsemi na toladi ']
# Skipped this pair :  [' a bethuel a horma a tsiklag na betweli na orima na tsikilagi ']
# Skipped this pair :  [' meshobab jamlec josha fils d amats meshobabi yamileki yosha mwana mobali ya amatsia ']
# Skipped this pair :  [' eljoenai jaakoba jeshochaia asaja adiel jesimiel benaja eliowenayi yakoba yeshoaya asaya adieli yesimieli benaya ']
# Skipped this pair :  [' fils de levi guershon kehath et merari . bana mibali ya levi gerishoni keati mpe merari . ']
# Skipped this pair :  ['eleazar engendra phinees phinees engendra abishua eleazari abotaki pineasi pineasi abotaki abishuwa ']
# Skipped this pair :  ['abishua engendra bukki bukki engendra uzzi abishuwa abotaki buki buki abotaki uzi ']
# Skipped this pair :  ['uzzi engendra zerachia zerachia engendra merajoth uzi abotaki zerakia zerakia abotaki merayoti ']
# Skipped this pair :  ['merajoth engendra amaria amaria engendra achitub merayoti abotaki amaria amaria abotaki ayitubi ']
# Skipped this pair :  ['achitub engendra tsadok tsadok engendra achimaats ayitubi abotaki tsadoki tsadoki abotaki ayimaatsi ']
# Skipped this pair :  ['achimaats engendra azaria azaria engendra jochanan ayimaatsi abotaki azaria azaria abotaki yoanani ']
# Skipped this pair :  ['azaria engendra amaria amaria engendra achitub azaria abotaki amaria amaria abotaki ayitubi ']
# Skipped this pair :  ['achitub engendra tsadok tsadok engendra shallum ayitubi abotaki tsadoki mpe tsadoki abotaki shalumi ']
# Skipped this pair :  ['shallum engendra hilkija hilkija engendra azaria shalumi abotaki ilikia ilikia abotaki azaria ']
# Skipped this pair :  ['azaria engendra seraja seraja engendra jehotsadak azaria abotaki seraya seraya abotaki yeotsadaki .']
# Skipped this pair :  [' fils de levi guershom kehath et merari . bana mibali ya levi gerishoni keati mpe merari . ']
# Skipped this pair :  ['voici les noms des fils de guershom libni et shimei . bana mibali ya gerishoni libini mpe shimei .']
# Skipped this pair :  [' fils d elkana amasai et achimoth elkana son fils bana mibali ya elikana amasayi ayimoti . ']
# Skipped this pair :  [' elkana tsophai son fils nachath son fils elikana abotaki tsofayi tsofayi abotaki naati ']
# Skipped this pair :  [' eliel obed et jaasiel metsobaja . elieli obedi mpe yaasieli bato ya metsobaya . ']
# Skipped this pair :  [' eluzai jerimoth bealia shemaria shephatia haruphien elewuzayi yerimoti bealia shemaria shefatia moto ya arofi ']
# Skipped this pair :  [' mishmanna le quatrieme jeremie le cinquieme mishimana mokonzi ya minei jeremi mokonzi ya mitano ']
# Skipped this pair :  [' atthai le sixieme eliel le septieme atayi mokonzi ya motoba elieli mokonzi ya sambo ']
# Skipped this pair :  [' jochanan le huitieme elzabad le neuvieme yoanani mokonzi ya mwambe elizabadi mokonzi ya libwa ']
# Skipped this pair :  [' jibhar elishua elpelet yibari elishuwa elipeleti ']
# Skipped this pair :  [' noga nepheg japhia noga nefegi yafia ']
# Skipped this pair :  [' elishama beeljada et eliphelet . elishama beliada mpe elifeleti . ']
# Skipped this pair :  ['david assembla aussi les enfants d aaron et les levites davidi asangisaki lisusu bakitani ya aron mpe balevi ']
# Skipped this pair :  ['des guershonites laedan et shimei . mpo na libota ya gerishoni laedani mpe shimei .']
# Skipped this pair :  ['fils de moise guershom et eliezer . bana mibali ya moyize gerishomi mpe eliezeri .']
# Skipped this pair :  [' fils de guershom shebuel le chef . bana mibali ya gerishomi shebueli azalaki mwana mobali ya liboso .']
# Skipped this pair :  [' de rechabia des fils de rechabia le chef jishija . yishiya mpo na etuka ya reabia ']
# Skipped this pair :  [' il batit bethlehem etam thekoa alendisaki beteleemi etami tekoa ']
# Skipped this pair :  [' beth tsur soco adullam beti tsuri soko adulami ']
# Skipped this pair :  [' gath maresha ziph gati maresha zifi ']
# Skipped this pair :  [' adoraim lakis azeka adorayimi lakishi azeka ']
# Skipped this pair :  ['la chose plut au roi et a toute l assemblee mokonzi mpe lisanga mobimba bandimaki mabongisi yango ']
# Skipped this pair :  [' les enfants de zaccai sept cent soixante bakitani ya zakayi nkama sambo na tuku motoba .']
# Skipped this pair :  [' les enfants de jora cent douze bakitani ya yora nkama moko na zomi na mibale .']
# Skipped this pair :  [' les enfants de guibbar quatre vingt quinze bakitani ya gibari tuku libwa na mitano .']
# Skipped this pair :  [' les gens de netopha cinquante six bato ya mboka netofa tuku mitano na motoba .']
# Skipped this pair :  [' les enfants d azmaveth quarante deux bato ya azimaveti tuku minei na mibale .']
# Skipped this pair :  [' les enfants de nebo cinquante deux bakitani ya nebo tuku mitano na mibale .']
# Skipped this pair :  [' les enfants de magbish cent cinquante six bakitani ya magibishi nkama moko na tuku mitano na motoba .']
# Skipped this pair :  [' les enfants de harim trois cent vingt bakitani ya arimi nkama misato na tuku mibale .']
# Skipped this pair :  [' les enfants d immer mille cinquante deux bakitani ya imeri nkoto moko na tuku mitano na mibale .']
# Skipped this pair :  [' les enfants de keros les enfants de siaha les enfants de padon kerosi siya padoni ']
# Skipped this pair :  [' les enfants de lebana les enfants de hagaba les enfants d akkub lebana agaba akubi ']
# Skipped this pair :  [' les enfants de hagab les enfants de shamlai les enfants de hanan agabi shalimayi anani ']
# Skipped this pair :  [' les enfants de guiddel les enfants de gachar les enfants de reaja gideli gaari reaya ']
# Skipped this pair :  [' les enfants de retsin les enfants de nekoda les enfants de gazzam retsini nekoda gazami ']
# Skipped this pair :  [' les enfants d uzza les enfants de paseach les enfants de besai uza paseya besayi ']
# Skipped this pair :  [' les enfants d asna les enfants de mehunim les enfants de nephusim asina mewunimi nefusimi ']
# Skipped this pair :  [' les enfants de bakbuk les enfants de hakupha les enfants de harhur bakibuki akufa aruri ']
# Skipped this pair :  [' les enfants de batsluth les enfants de mehida les enfants de harsha batsiluti meyida arisha ']
# Skipped this pair :  [' les enfants de barkos les enfants de sisra les enfants de tamach barikosi sisera tama ']
# Skipped this pair :  [' les enfants de netsiach les enfants de hatipha . netsia mpe atifa .']
# Skipped this pair :  [' les enfants de jaala les enfants de darkon les enfants de guiddel yala darikoni gideli ']
# Skipped this pair :  ['des enfants d immer hanani et zebadia . kati na bakitani ya imeri anani mpe zebadia .']
# Skipped this pair :  [' benjamin malluc et shemaria . benjame maluki mpe shemaria . ']
# Skipped this pair :  [' des enfants de bani maadai amram uel kati na bakitani ya bani madayi amirami ueli ']
# Skipped this pair :  [' benaja bedia keluhu benaya bedia keluwu ']
# Skipped this pair :  [' vania meremoth eliashib vania meremoti eliashibi ']
# Skipped this pair :  [' matthania matthenai jaasai matania matinayi yasayi ']
# Skipped this pair :  [' bani binnui shimei bani binuwi shimei ']
# Skipped this pair :  [' shelemia nathan adaja shelemiya natan adaya ']
# Skipped this pair :  [' macnadbai shashai sharai makinadibayi shashayi sharayi ']
# Skipped this pair :  [' azareel shelemia shemaria azareyeli shelemiya shemaria ']
# Skipped this pair :  [' shallum amaria et joseph . shalumi amaria mpe jozefi . ']
# Skipped this pair :  [' les enfants de zaccai sept cent soixante bakitani ya zakayi nkama sambo na tuku motoba .']
# Skipped this pair :  [' les enfants de hariph cent douze bakitani ya arifi nkama moko na zomi na mibale .']
# Skipped this pair :  [' les enfants de gabaon quatre vingt quinze bakitani ya mboka gabaoni tuku libwa na mitano .']
# Skipped this pair :  [' les gens de beth azmaveth quarante deux bato ya mboka beti azimaveti tuku minei na mibale .']
# Skipped this pair :  [' les gens de l autre nebo cinquante deux bato ya mboka nebo mosusu tuku mitano na mibale .']
# Skipped this pair :  [' les enfants de harim trois cent vingt bato ya mboka arimi nkama misato na tuku mibale .']
# Skipped this pair :  [' les enfants d immer mille cinquante deux bakitani ya imeri nkoto moko na tuku mitano na mibale .']
# Skipped this pair :  [' les enfants de harim mille dix sept . bakitani ya arimi nkoto moko na zomi na sambo .']
# Skipped this pair :  [' les enfants de keros les enfants de sia les enfants de padon kerosi siya padoni ']
# Skipped this pair :  [' les enfants de lebana les enfants de hagaba les enfants de salmai lebana agaba shalimayi ']
# Skipped this pair :  [' les enfants de hanan les enfants de guiddel les enfants de gachar anani gideli gaari ']
# Skipped this pair :  [' les enfants de reaja les enfants de retsin les enfants de nekoda reaya retsini nekoda ']
# Skipped this pair :  [' les enfants de gazam les enfants d uzza les enfants de paseach gazami uza paseya ']
# Skipped this pair :  [' les enfants de besai les enfants de meunim les enfants de nephishesim besayi mewunimi nefusimi ']
# Skipped this pair :  [' les enfants de bakbuk les enfants de hakupha les enfants de harhur bakibuki akufa aruri ']
# Skipped this pair :  [' les enfants de batslith les enfants de mehida les enfants de harsha batsiliti meyida arisha ']
# Skipped this pair :  [' les enfants de barkos les enfants de sisera les enfants de thamach barikosi sisera tama ']
# Skipped this pair :  [' les enfants de netsiach les enfants de hatipha . netsia mpe atifa .']
# Skipped this pair :  [' les enfants de jaala les enfants de darkon les enfants de guiddel yala darikoni gideli ']
# Skipped this pair :  [' seraja azaria jeremie seraya azaria jeremi ']
# Skipped this pair :  [' pashur amaria malkija pashuri amaria malikiya ']
# Skipped this pair :  [' hattush shebania malluc atushi shebania maluki ']
# Skipped this pair :  [' harim meremoth obadia arimi meremoti abidiasi ']
# Skipped this pair :  [' daniel guinnethon baruc daniele ginetoni baruki ']
# Skipped this pair :  [' meshullam abija mijamin meshulami abiya miyamini ']
# Skipped this pair :  [' mica rehob hashabia mishe reobi ashabia ']
# Skipped this pair :  [' zaccur sherebia shebania zakuri sherebia shebania ']
# Skipped this pair :  [' hodija bani beninu . odia bani mpe beninu . ']
# Skipped this pair :  [' bunni azgad bebai buni azigadi bebayi ']
# Skipped this pair :  [' adonija bigvai adin adoniya bigivayi adini ']
# Skipped this pair :  [' ater ezechias azzur ateri ezekiasi azuri ']
# Skipped this pair :  [' hodija hashum betsai odia ashumi betsayi ']
# Skipped this pair :  [' hariph anathoth nebai arifi anatoti nebayi ']
# Skipped this pair :  [' magpiash meshullam hezir magipiashi meshulami eziri ']
# Skipped this pair :  [' meshezabeel tsadok jaddua meshezabeyeli tsadoki yaduwa ']
# Skipped this pair :  [' pelatia hanan anaja pelatia anani anaya ']
# Skipped this pair :  [' osee hanania hashub oze anania ashubi ']
# Skipped this pair :  [' lochesh pilcha shobek aloeshi pila shobeki ']
# Skipped this pair :  [' rehum hashabna maaseja rewumi ashabina maaseya ']
# Skipped this pair :  [' achija hanan anan ayiya anani anane ']
# Skipped this pair :  [' malluc harim baana . maluki arimi baana . ']
# Skipped this pair :  [' a jeshua a molada a beth palet kati na yeshua kati na molada kati na beti paleti ']
# Skipped this pair :  [' a en rimmon a tsora a jarmuth kati na eini rimoni kati na tsorea kati na yarimuti ']
# Skipped this pair :  [' a anathoth nob anania kati na anatoti nobi mpe anania ']
# Skipped this pair :  [' hatsor rama guitthaim kati na atsori rama mpe gitayimi ']
# Skipped this pair :  [' hadid tseboim neballat kati na adidi tseboyimi mpe nebalati ']
# Skipped this pair :  [' amaria malluc hattush amaria maluki atushi ']
# Skipped this pair :  [' shecania rehum meremoth shekania rewumi meremoti ']
# Skipped this pair :  [' iddo guinnethoi abija ido ginetoyi abiya ']
# Skipped this pair :  [' mijamin maadia bilga miyamini maadia biliga ']
# Skipped this pair :  [' shemaja jojarib jedaja shemaya yoyaribi yedaeya ']
# Skipped this pair :  [' jojada engendra jonathan et jonathan engendra jaddua . yoyada abotaki jonatan jonatan abotaki yaduwa . ']
# Skipped this pair :  [' azaria esdras meshullam azaria esidrasi meshulami ']
# Skipped this pair :  ['alors tous ses disciples l ayant abandonne s enfuirent . bayekoli na ye nyonso basundolaki ye mpe bakimaki .']
# Skipped this pair :  [' il leur laissa son vetement et s enfuit nu de leurs mains . asundolaki liputa mpe akimaki .']
# Skipped this pair :  ['et ils crierent de nouveau crucifie le . bagangaki lisusu baka ye na ekulusu !']
# Skipped this pair :  ['car rien n est impossible a dieu . pamba te nzambe alembanaka eloko te .']
# Skipped this pair :  [' alors marie dit mon ame magnifie le seigneur bongo mari alobaki molimo na ngai ezali kokumisa nkolo ']
# Skipped this pair :  ['mais ils ne comprirent point ce qu il leur disait . kasi basosolaki te maloba na ye .']
# Skipped this pair :  ['et toute chair verra le salut de dieu . mpe bato nyonso bakomona lobiko ya nzambe . ']
# Skipped this pair :  ['alors le peuple lui demanda que ferons nous donc ? ebele ya bato batunaki ye tosengeli kosala nini ?']
# Skipped this pair :  ['voici ce que cette parabole signifie . tala ndimbola ya lisese yango nkona ezali liloba na nzambe .']
# Skipped this pair :  ['et voici deux hommes s entretenaient avec lui mibali mibale bazalaki kosolola na yesu moyize mpe eliya']
# Skipped this pair :  ['donne nous chaque jour notre pain quotidien pesa biso bilei oyo tosengeli na yango mokolo na mokolo ']
# Skipped this pair :  ['et ils ne purent lui repondre sur cela . bakokaki te kopesa ye eyano .']
# Skipped this pair :  ['mais il leur dit cette parabole bongo yesu alobaki na bango lisese oyo ']
# Skipped this pair :  ['souvenez vous de la femme de lot . bokanisa makambo oyo ekomelaki mwasi ya loti !']
# Skipped this pair :  ['et ils repondirent le seigneur en a besoin . bazongisaki nkolo azali na bosenga na yango .']
# Skipped this pair :  [' le second epousa sa femme et mourut sans enfants . ndeko ya mibale abalaki mwasi yango kaka ']
# Skipped this pair :  ['apres eux tous la femme mourut aussi . sima na bango nyonso mwasi yango mpe akufaki . ']
# Skipped this pair :  ['et ils n osaient plus lui faire aucune question . mpe moko te amekaki lisusu kotuna ye mituna .']
# Skipped this pair :  ['possedez vos ames par votre patience . boyika mpiko mpe bokozwa bomoi . ']
# Skipped this pair :  [' et pierre etant sorti pleura amerement . abimaki mpe alelaki makasi na libanda .']
# Skipped this pair :  ['alors pilate prononca que ce qu ils demandaient fut fait . pilato azwaki mokano ya kokokisa oyo basengaki ']
# Skipped this pair :  ['et elles se souvinrent de ses paroles . boye bakanisaki maloba ya yesu . ']
# Skipped this pair :  ['elle etait au commencement avec dieu . wuta na ebandeli azalaka elongo na nzambe . ']
# Skipped this pair :  [' or ceux qui avaient ete envoyes etaient des pharisiens . nzokande batindami yango bazalaki bafarizeo .']
# Skipped this pair :  ['nicodeme lui dit comment ces choses se peuvent elles faire ? nikodemi atunaki lisusu ekosalema ndenge nini ?']
# Skipped this pair :  [' or il fallait qu il passat par la samarie . lokola asengelaki kolekela na samari ']
# Skipped this pair :  ['je suis le pain de vie . pamba te nazali lipa oyo epesaka bomoi .']
# Skipped this pair :  ['le peuple etait donc partage a son sujet . ezali bongo nde bato bakabwanaki na tina na yesu .']
# Skipped this pair :  [' moi et le pere nous sommes un . ngai mpe tata tozali se moko .']
# Skipped this pair :  ['et plusieurs crurent en lui en ce lieu la . mpe kuna bato mingi bandimaki yesu . ']
# Skipped this pair :  ['alors jesus leur dit ouvertement lazare est mort . bongo yesu alobaki na bango na polele lazare akufi .']
# Skipped this pair :  ['jesus lui dit ton frere ressuscitera . yesu alobaki na ye ndeko na yo akosekwa .']
# Skipped this pair :  ['et jesus pleura . yesu alelaki .']
# Skipped this pair :  [' si vous m aimez gardez mes commandements . soki bolingaka ngai bokobatela mibeko na ngai . ']
# Skipped this pair :  ['jesus leur repondit vous croyez maintenant ? yesu azongiselaki bango bondimi sik oyo ?']
# Skipped this pair :  ['mais ce fut salomon qui lui batit un temple . kasi salomo nde moto atongelaki ye ndako .']
# Skipped this pair :  ['mais dieu l a ressuscite des morts kasi nzambe asekwisaki ye kati na bakufi ']
# Skipped this pair :  ['et ils y annoncerent l evangile . kuna mpe lisusu bakobaki kaka koteya sango malamu . ']
# Skipped this pair :  ['et ils demeurerent la longtemps avec les disciples . mpe bawumelaki wana tango molayi elongo na bayekoli .']
# Skipped this pair :  ['toutes les ouvres de dieu lui sont connues de toute eternite . makambo oyo eyebana wuta kala . ']
# Skipped this pair :  [' toutefois silas jugea a propos de rester . kasi silasi asepelaki kotikala wana . ']
# Skipped this pair :  ['ainsi paul sortit du milieu d eux . na bongo polo atikaki bango . ']
# Skipped this pair :  ['et il les renvoya du tribunal . boye abenganaki bango na esambiselo . ']
# Skipped this pair :  ['et ils etaient en tout environ douze hommes . bango nyonso bazalaki bato pene zomi na mibale .']
# Skipped this pair :  [' il ecrivit une lettre ainsi concue boye akomelaki moyangeli mokanda oyo ']
# Skipped this pair :  [' tous alors ayant pris courage mangerent aussi . bango nyonso balendisamaki mpe bakomaki kolia .']
# Skipped this pair :  [' qui rendra a chacun selon ses ouvres nzambe akofuta moto na moto kolanda misala na ye ']
# Skipped this pair :  ['car dieu n a point egard a l apparence des personnes . pamba te nzambe aponaka bilongi te .']
# Skipped this pair :  ['ils n ont point connu le chemin de la paix . bayebi nzela ya kimia te .']
# Skipped this pair :  [' je vous en supplie donc soyez mes imitateurs . boye nabondeli bino bolanda ndakisa na ngai . ']
# Skipped this pair :  [' que tout ce que vous faites se fasse avec charite . bosalaka makambo nyonso na bolingo .']
# Skipped this pair :  ['et elles glorifiaient dieu a cause de moi . mpe bazalaki kokumisa nzambe na tina na ngai .']
# Skipped this pair :  ['un peu de levain fait lever toute la pate . mwa levire moke evimbisaka potopoto nyonso ya mapa .']
# Skipped this pair :  ['et ne donnez point acces au diable . bopesaka na satana nzela te .']
# Skipped this pair :  ['n ayez donc point de part avec eux . bosanganaka te elongo na bato wana .']
# Skipped this pair :  ['examinez ce qui est agreable au seigneur . bosalaka makasi mpo na kososola makambo oyo esepelisaka nkolo .']
# Skipped this pair :  ['faites toutes choses sans murmures et sans disputes bosalaka likambo moko te na koyimayima mpe na tembe ']
# Skipped this pair :  ['soyez toujours joyeux . bozalaka na esengo tango nyonso ']
# Skipped this pair :  ['priez sans cesse . bosambelaka na kolemba te ']
# Skipped this pair :  ['n eteignez point l esprit . bopekisaka te mosala ya molimo mosantu ']
# Skipped this pair :  ['ne meprisez point les propheties . botiolaka masakoli te']
# Skipped this pair :  ['abstenez vous de toute apparence de mal . boboyaka mabe ya lolenge nyonso .']
# Skipped this pair :  [' freres priez pour nous . bandeko bobondelaka mpo na biso . ']
# Skipped this pair :  ['annonce et enseigne ces choses . teya makambo yango mpe tinda bato kosalela yango .']
# Skipped this pair :  ['tache de venir bientot vers moi sala makasi ete oya noki epai na ngai .']
# Skipped this pair :  ['j ai envoye tychique a ephese . natindaki tishike na efeso .']
# Skipped this pair :  [' exhorte de meme les jeunes hommes a etre sages lendisa mpe bilenge mibali ete bamibatelaka malamu .']
# Skipped this pair :  ['car notre dieu est aussi un feu devorant . pamba te nzambe na biso azali moto oyo ezikisaka .']
# Skipped this pair :  ['que l amour fraternel demeure . tika ete bondeko ewumela kati na bino !']
# Skipped this pair :  ['la grace soit avec vous tous ! amen . tika ete ngolu ya nzambe ezala na bino nyonso !']
# Skipped this pair :  [' mes freres bien aimes ne vous y trompez point bandeko balingami bomikosa te ']
# Skipped this pair :  [' puisque vous avez goute que le seigneur est bon awa bosili kososola ete nkolo azali malamu .']
# Trimmed to 0 sentence pairs
# Counting words...
# Counted words:
# français 3
# lingala 3

# %%
input_lang.name
# Out:
# 'français'

# %%
if pairs:
  print("okay")

# %%
# print("Saving Dictionary")
# pickle.dump(input_lang, open('save/input.pkl', 'wb'))
# pickle.dump(output_lang, open('save/output.pkl', 'wb'))

# %% [markdown]
# Utility functions to create tensors from sentences
#
# Tensor - A tensor is a generalization of vectors and matrices and is easily understood as a multidimensional array.

# %%
def indexesFromSentence(lang, sentence):
    words = sentence.split(' ')
    indexes = []
    for word in words:
        if word not in lang.word2index.keys():
            indexes.append(lang.word2index["UNK"])
        else:
            indexes.append(lang.word2index[word])

    return indexes
    #return [lang.word2index[word] for word in words]


def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# # 3. Model Architecture (The Seq2Seq Model)
# A Sequence to Sequence network (also known as seq2seq network, or Encoder Decoder network) is a model consisting of two RNNs called the encoder and decoder. The encoder reads an input sequence and outputs a single vector, and the decoder reads that vector to produce an output sequence.
#
# model
#
# Unlike sequence prediction with a single RNN, where every input corresponds to an output, the seq2seq model frees us from sequence length and order, which makes it ideal for translation between two languages.
#
# With a seq2seq model the encoder creates a single vector which, in the ideal case, encodes the “meaning” of the input sequence into a single vector — a single point in some N dimensional space of sentences. Let's look into the Encoder -
#
#
# # The Encoder
# The encoder of a seq2seq network is a RNN that outputs some value for every word from the input sentence. For every input word the encoder outputs a vector and a hidden state, and uses the hidden state for the next input word.
#
#
#
# Note - Refer this Link if you aren't familiar with RNN (Recurrent Neural Network), GRU, LSTM, Hidden State etc.
# Let's implement an Encoder. We'll use LSTM units.
#
# Let's implement an Encoder. We'll use LSTM units.

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, layers=1):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.layers = layers
        # -----------------------------------------------------------------
        # self.weight_matrix = create_weight_matrix()
        # self.embedding, num_embeddings, embedding_dim = create_emb_layer(self.weight_matrix, True)
        self.embedding = nn.Embedding(input_size, hidden_size, layers)

        # -------------------------------------------------------------------
        # self.gru = nn.GRU(embedding_dim, hidden_size)
        self.lstm = nn.LSTM(hidden_size, hidden_size, layers)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.lstm(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(self.layers, 1, self.hidden_size, device=device), torch.zeros(self.layers, 1, self.hidden_size, device=device)

# %% [markdown]
# # The Decoder
# The decoder is another RNN that takes the encoder output vector(s) and outputs a sequence of words to create the translation. In the simplest seq2seq decoder we use only last output of the encoder. This last output is sometimes called the context vector as it encodes context from the entire sequence. This context vector is used as the initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and hidden state. The initial input token is the start-of-string token, and the first hidden state is the context vector (the encoder’s last hidden state).
#
# decoder
#
# Let's implement the decoder using LSTM units.

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %% [markdown]
# We know have both Encoder and Decoder with us. We can go ahead and train the model. But before that Let's look into the concepts of Attention.
#
# # Attention
# If only the context vector is passed betweeen the encoder and decoder, that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to “focus” on a different part of the encoder’s outputs for every step of the decoder’s own outputs. First we calculate a set of attention weights. These will be multiplied by the encoder output vectors to create a weighted combination. The result (called attn_applied in the code) should contain information about that specific part of the input sequence, and thus help the decoder choose the right output words.
#
# attn
#
# Let's implement a decoder with attention. We'll use this decoder for our final model.

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH, layers=1):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length
        self.layers = layers

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.lstm = nn.LSTM(self.hidden_size, self.hidden_size, self.layers)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        #print("d0", embedded.shape)
        # print("d1", embedded[0].shape)
        # print("d2----", hidden[0][0].shape)
        #
        # m = torch.cat((embedded[0], hidden[0][0]), 1)
        # print("d3", m.shape)
        # r = self.attn(m)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0][0]), 1)), dim=1)

        # print("d4", attn_weights.shape)
        # print("d5", encoder_outputs.unsqueeze(0).shape)

        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)

        output, hidden = self.lstm(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(self.layers, 1, self.hidden_size, device=device), torch.zeros(self.layers, 1, self.hidden_size, device=device)

# %% [markdown]
# # Training utility¶
# To train we run the input sentence through the encoder, and keep track of every output and the latest hidden state. Then the decoder is given the token as its first input, and the last hidden state of the encoder as its first hidden state.

# %%
def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# The whole training process will go like this:
#
# Start a timer
# Initialize optimizers and criterion
# Create set of training pairs
# Start empty losses array for plotting
# Then we call train many times and occasionally print the progress (% of examples, time so far, estimated time) and average loss.

# %%
def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

        if iter % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    #print(plot_losses)
    showPlot(plot_losses)
    #pickle.dump(plot_losses, open('save/gru1n.pkl', 'wb'))

# %% [markdown]
# # Evaluation Utility¶
# Evaluation is mostly the same as training, but there are no targets so we simply feed the decoder’s predictions back to itself for each step. Every time it predicts a word we add it to the output string, and if it predicts the EOS token we stop there. We also store the decoder’s attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]


def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, attentions = evaluate(encoder, decoder, pair[0])
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        # Bleu
        ref = [pair[1].split()]
        bl = bleu.sentence_bleu(ref, output_sentence.split())
        print("BLEU Score", bl)
        print('')

# %% [markdown]
# # Visualization Utility¶
# Plotting is done with matplotlib, using the array of loss values plot_losses saved while training.
#
# We can also plot the attention because it has highly interpretable outputs. It is used to weight specific encoder outputs of the input sequence, we can imagine looking where the network is focused most at each time step.

# %%
def showPlot(points):
    #print("function called")
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)
    plt.xlabel("steps")
    plt.ylabel("loss")
    plt.show()
    fig.savefig('loss.png')

def showAttention(input_sentence, output_words, attentions, attr):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)

    i = attentions.shape[0]
    attn = [a[:i+2].tolist() for a in attentions]


    cax = ax.matshow(attn, cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)

    hindi_font = FontProperties(fname = '../input/nirmala-font/Nirmala.ttf')
    ax.set_yticklabels([''] + output_words, fontproperties=hindi_font)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    fig.savefig("attention_{}.png".format(attr))
    plt.show()


def evaluateAndShowAttention(encoder1, attn_decoder1, input_sentence, attr):
    output_words, attentions = evaluate(
        encoder1, attn_decoder1, input_sentence)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions, attr)

# %% [markdown]
# Some helper functions to print time elapsed and estimated time remaining given the current time and progress %.

# %%
def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# Finally, a wrapper function to run the experiment.¶

# %%
def run_training():
    print("========== Building Encoder... ==========\n")
    encoder1 = EncoderRNN(input_lang.n_words, hidden_size, layers=1).to(device)
    print(encoder1)
    print('\n')
    eparam = count_parameters(encoder1)
    print('\n')
    print("========== Building Decoder... ==========\n")
    attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1, layers=1).to(device)
    print(attn_decoder1)
    print('\n')
    dparam = count_parameters(attn_decoder1)
    print("\nTotal parameters in encoder + decoder : ", eparam+dparam)
    print('\n')
    print("========== Starting Training... ==========\n")
    trainIters(encoder1, attn_decoder1, 50000, print_every=1000)
    print("========== Finished Training... ==========\n")
    # Evaluation and Visualization

    return encoder1, attn_decoder1

# %%
encoder1, attn_decoder1 = run_training()
# Out:
# ========== Building Encoder... ==========
#
# EncoderRNN(
#   (embedding): Embedding(3, 1000, padding_idx=1)
#   (lstm): LSTM(1000, 1000)
# )
#
#
# +-------------------+------------+
# |      Modules      | Parameters |
# +-------------------+------------+
# |  embedding.weight |    3000    |
# | lstm.weight_ih_l0 |  4000000   |
# | lstm.weight_hh_l0 |  4000000   |
# |  lstm.bias_ih_l0  |    4000    |
# |  lstm.bias_hh_l0  |    4000    |
# +-------------------+------------+
# Total Trainable Params: 8011000
#
#
# ========== Building Decoder... ==========
#
# AttnDecoderRNN(
#   (embedding): Embedding(3, 1000)
#   (attn): Linear(in_features=2000, out_features=20, bias=True)
#   (attn_combine): Linear(in_features=2000, out_features=1000, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (lstm): LSTM(1000, 1000)
#   (out): Linear(in_features=1000, out_features=3, bias=True)
# )
#
#
# +---------------------+------------+
# |       Modules       | Parameters |
# +---------------------+------------+
# |   embedding.weight  |    3000    |
# |     attn.weight     |   40000    |
# |      attn.bias      |     20     |
# | attn_combine.weight |  2000000   |
# |  attn_combine.bias  |    1000    |
# |  lstm.weight_ih_l0  |  4000000   |
# |  lstm.weight_hh_l0  |  4000000   |
# |   lstm.bias_ih_l0   |    4000    |
# |   lstm.bias_hh_l0   |    4000    |
# |      out.weight     |    3000    |
# |       out.bias      |     3      |
# +---------------------+------------+
# Total Trainable Params: 10055023
#
# Total parameters in encoder + decoder :  18066023
#
#
# ========== Starting Training... ==========
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-92-1c941e767979> in <cell line: 1>()
# ----> 1 encoder1, attn_decoder1 = run_training()
#
# <ipython-input-91-d897dadd6459> in run_training()
#      14     print('\n')
#      15     print("========== Starting Training... ==========\n")
# ---> 16     trainIters(encoder1, attn_decoder1, 50000, print_every=1000)
#      17     print("========== Finished Training... ==========\n")
#      18     # Evaluation and Visualization
#
# <ipython-input-87-09e9b9c7f369> in trainIters(encoder, decoder, n_iters, print_every, plot_every, learning_rate)
#       7     encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
#       8     decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
# ----> 9     training_pairs = [tensorsFromPair(random.choice(pairs))
#      10                       for i in range(n_iters)]
#      11     criterion = nn.NLLLoss()
#
# <ipython-input-87-09e9b9c7f369> in <listcomp>(.0)
#       7     encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
#       8     decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
# ----> 9     training_pairs = [tensorsFromPair(random.choice(pairs))
#      10                       for i in range(n_iters)]
#      11     criterion = nn.NLLLoss()
#
# /usr/lib/python3.10/random.py in choice(self, seq)
#     376         """Choose a random element from a non-empty sequence."""
#     377         # raises IndexError if seq is empty
# --> 378         return seq[self._randbelow(len(seq))]
#     379
#     380     def shuffle(self, x, random=None):
#
# IndexError: list index out of range

# %% [markdown]
# Let's check our machine translation system on some examples

# %%
evaluateRandomly(encoder1, attn_decoder1)

# %% [markdown]
# The above example were from the data itself. so it perfromed really well. Let's check on some out of the data examples.

# %%
output_words, attentions = evaluate(
        encoder1, attn_decoder1, "He is going home")
print(" ".join(output_words))

# %%
evaluateAndShowAttention(encoder1, attn_decoder1, "Et Dieu nomma la lumière, jour; et il nomma les ténèbres, nuit. Et il y eut un soir, et il y eut un matin; ce fut le premier jour", "sent-1")

# %%
evaluateAndShowAttention(encoder1, attn_decoder1, "jesus fils de david", "sent-2")

# %%
evaluateAndShowAttention(encoder1, attn_decoder1, "Au commencement, Dieu créa les cieux et la terre", "sent-2")

# %% [markdown]
# Conclusion - This is a very simple architecture trained a small dataset. Yet, the model has learned pretty good for small sentences. It can be futher improved by training it on large corpus.
#
# If you found this project interesting consider UPVOTING it. Thanks!
# References
#
# Ilya Sutskever, Oriol Vinyals, Quoc V. Le Sequence to sequence learning with neural networks
# Dzmitry Bahdanau, KyungHyun Cho, Yoshua Bengio∗ (2016) Neural machine translation by jointly learning to align and translate
# Happy Learning!
